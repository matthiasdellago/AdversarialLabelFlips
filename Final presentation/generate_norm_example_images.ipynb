# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
l0 = np.zeros( (5,5) )
l0[2,2] = 3
plt.imshow(l0, cmap="plasma")
plt.savefig("plots/L0.png")

# %%
l1 = np.random.rand(5,5) - 0.5
plt.imshow(l1, cmap="plasma")
plt.savefig("plots/L1.png")
l1
# Out:
# array([[ 0.1156129 , -0.18690642,  0.33220018, -0.39845441, -0.36086584],
#        [-0.12478426, -0.4314415 ,  0.21443186,  0.15570883, -0.04222017],
#        [ 0.407256  ,  0.24969633,  0.479294  ,  0.20683912, -0.12918295],
#        [ 0.15900524, -0.16693513,  0.17600191, -0.43548606,  0.14523582],
#        [-0.00058751,  0.38155331,  0.13006176, -0.20039729,  0.18413349]])

# %%
l2 = np.sqrt(np.abs(l1))*np.sign(l1)
plt.imshow(l2, cmap="plasma")
plt.savefig("plots/L2.png")

# %%
linf = np.sign(l1)
plt.imshow(linf,vmin = -5, vmax = 5, cmap="plasma")
plt.savefig("plots/Linf.png")
